# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# ## Load Data

# %%
file = "C:/Users/marku/Documents/Programmering/Credit_Risk_Predictor/2019_public_lar_three_year_csv.csv"

condition = lambda x: x == 1
condition2 = lambda x: x == 2

df = pd.read_csv(file, converters={'loan_purpose': condition, 'business_or_commercial_purpose': condition2}, nrows = 1100)

# %%
df.head()
# Out:
#    activity_year                   lei derived_msa_md state_code  county_code  \
# 0           2019  549300FNXYY540N23N64           None         CT         9003
# 1           2019  549300FNXYY540N23N64           None         PA        42017
# 2           2019  549300FNXYY540N23N64           None         NJ        34039
# 3           2019  549300FNXYY540N23N64           None         PA        42055
# 4           2019  549300FNXYY540N23N64           None         MT        30111
#
#    census_tract conforming_loan_limit derived_loan_product_type  \
# 0    9003416400                     C            FHA:First Lien
# 1   42017102401                     C   Conventional:First Lien
# 2   34039034300                     C            FHA:First Lien
# 3   42055011302                     C            FHA:First Lien
# 4   30111000702                     C   Conventional:First Lien
#
#               derived_dwelling_category       derived_ethnicity  ...  \
# 0  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino  ...
# 1  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino  ...
# 2  Single Family (1-4 Units):Site-Built      Hispanic or Latino  ...
# 3  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino  ...
# 4  Single Family (1-4 Units):Site-Built  Not Hispanic or Latino  ...
#
#   denial_reason_2 denial_reason_3  denial_reason_4  tract_population  \
# 0             NaN             NaN              NaN              3286
# 1             NaN             NaN              NaN              3765
# 2             NaN             NaN              NaN              3932
# 3             NaN             NaN              NaN              5844
# 4             NaN             NaN              NaN              7934
#
#    tract_minority_population_percent  ffiec_msa_md_median_family_income  \
# 0                              21.58                              98400
# 1                               4.70                             110100
# 2                              75.43                              98600
# 3                              10.40                              76400
# 4                              15.15                              73700
#
#    tract_to_msa_income_percentage  tract_owner_occupied_units  \
# 0                           99.73                        1077
# 1                           84.24                        1116
# 2                           83.56                        1138
# 3                          116.35                        1769
# 4                          113.72                        2108
#
#    tract_one_to_four_family_homes  tract_median_age_of_housing_units
# 0                            1294                                 59
# 1                            1295                                 54
# 2                            1395                                 60
# 3                            2259                                 36
# 4                            2879                                 28
#
# [5 rows x 99 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 99 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   activity_year                             1100 non-null   int64
#  1   lei                                       1100 non-null   object
#  2   derived_msa_md                            1100 non-null   object
#  3   state_code                                1100 non-null   object
#  4   county_code                               1100 non-null   int64
#  5   census_tract                              1100 non-null   int64
#  6   conforming_loan_limit                     1100 non-null   object
#  7   derived_loan_product_type                 1100 non-null   object
#  8   derived_dwelling_category                 1100 non-null   object
#  9   derived_ethnicity                         1100 non-null   object
#  10  derived_race                              1100 non-null   object
#  11  derived_sex                               1100 non-null   object
#  12  action_taken                              1100 non-null   int64
#  13  purchaser_type                            1100 non-null   int64
#  14  preapproval                               1100 non-null   int64
#  15  loan_type                                 1100 non-null   int64
#  16  loan_purpose                              1100 non-null   bool
#  17  lien_status                               1100 non-null   int64
#  18  reverse_mortgage                          1100 non-null   int64
#  19  open_end_line_of_credit                   1100 non-null   int64
#  20  business_or_commercial_purpose            1100 non-null   bool
#  21  loan_amount                               1100 non-null   int64
#  22  combined_loan_to_value_ratio              205 non-null    float64
#  23  interest_rate                             791 non-null    float64
#  24  rate_spread                               175 non-null    float64
#  25  hoepa_status                              1100 non-null   int64
#  26  total_loan_costs                          772 non-null    float64
#  27  total_points_and_fees                     0 non-null      float64
#  28  origination_charges                       772 non-null    float64
#  29  discount_points                           74 non-null     float64
#  30  lender_credits                            51 non-null     float64
#  31  loan_term                                 1083 non-null   float64
#  32  prepayment_penalty_term                   0 non-null      float64
#  33  intro_rate_period                         7 non-null      float64
#  34  negative_amortization                     1100 non-null   int64
#  35  interest_only_payment                     1100 non-null   int64
#  36  balloon_payment                           1100 non-null   int64
#  37  other_nonamortizing_features              1100 non-null   int64
#  38  property_value                            812 non-null    float64
#  39  construction_method                       1100 non-null   int64
#  40  occupancy_type                            1100 non-null   int64
#  41  manufactured_home_secured_property_type   1100 non-null   int64
#  42  manufactured_home_land_property_interest  1100 non-null   int64
#  43  total_units                               1100 non-null   int64
#  44  multifamily_affordable_units              0 non-null      float64
#  45  income                                    933 non-null    float64
#  46  debt_to_income_ratio                      232 non-null    object
#  47  applicant_credit_score_type               1100 non-null   int64
#  48  co_applicant_credit_score_type            1100 non-null   int64
#  49  applicant_ethnicity_1                     1100 non-null   int64
#  50  applicant_ethnicity_2                     59 non-null     float64
#  51  applicant_ethnicity_3                     0 non-null      float64
#  52  applicant_ethnicity_4                     0 non-null      float64
#  53  applicant_ethnicity_5                     0 non-null      float64
#  54  co_applicant_ethnicity_1                  1100 non-null   int64
#  55  co_applicant_ethnicity_2                  11 non-null     float64
#  56  co_applicant_ethnicity_3                  0 non-null      float64
#  57  co_applicant_ethnicity_4                  0 non-null      float64
#  58  co_applicant_ethnicity_5                  0 non-null      float64
#  59  applicant_ethnicity_observed              1100 non-null   int64
#  60  co_applicant_ethnicity_observed           1100 non-null   int64
#  61  applicant_race_1                          1100 non-null   int64
#  62  applicant_race_2                          26 non-null     float64
#  63  applicant_race_3                          0 non-null      float64
#  64  applicant_race_4                          0 non-null      float64
#  65  applicant_race_5                          0 non-null      float64
#  66  co_applicant_race_1                       1100 non-null   int64
#  67  co_applicant_race_2                       14 non-null     float64
#  68  co_applicant_race_3                       0 non-null      float64
#  69  co_applicant_race_4                       0 non-null      float64
#  70  co_applicant_race_5                       0 non-null      float64
#  71  applicant_race_observed                   1100 non-null   int64
#  72  co_applicant_race_observed                1100 non-null   int64
#  73  applicant_sex                             1100 non-null   int64
#  74  co_applicant_sex                          1100 non-null   int64
#  75  applicant_sex_observed                    1100 non-null   int64
#  76  co_applicant_sex_observed                 1100 non-null   int64
#  77  applicant_age                             1100 non-null   object
#  78  co_applicant_age                          1100 non-null   object
#  79  applicant_age_above_62                    1024 non-null   object
#  80  co_applicant_age_above_62                 431 non-null    object
#  81  submission_of_application                 1100 non-null   int64
#  82  initially_payable_to_institution          1100 non-null   int64
#  83  aus_1                                     1100 non-null   int64
#  84  aus_2                                     122 non-null    float64
#  85  aus_3                                     1 non-null      float64
#  86  aus_4                                     0 non-null      float64
#  87  aus_5                                     0 non-null      float64
#  88  denial_reason_1                           1100 non-null   int64
#  89  denial_reason_2                           3 non-null      float64
#  90  denial_reason_3                           0 non-null      float64
#  91  denial_reason_4                           0 non-null      float64
#  92  tract_population                          1100 non-null   int64
#  93  tract_minority_population_percent         1100 non-null   float64
#  94  ffiec_msa_md_median_family_income         1100 non-null   int64
#  95  tract_to_msa_income_percentage            1100 non-null   float64
#  96  tract_owner_occupied_units                1100 non-null   int64
#  97  tract_one_to_four_family_homes            1100 non-null   int64
#  98  tract_median_age_of_housing_units         1100 non-null   int64
# dtypes: bool(2), float64(39), int64(44), object(14)
# memory usage: 835.9+ KB

# %% [markdown]
# ## Dropping any non-key data fields

# %%
# Columns to keep based on articles. 'loan_purpose' not included since it is already filtered

columns_to_keep = ['loan_type', 'loan_amount', 'action_taken', 'occupancy_type', 'census_tract', 'applicant_ethnicity_1', 
                   'co_applicant_ethnicity_1', 'applicant_race_1', 'applicant_race_2', 'co_applicant_race_1', 'co_applicant_race_2', 
                   'applicant_sex', 'co_applicant_sex', 'applicant_age', 'co_applicant_age', 'income', 'lien_status', 
                   'applicant_credit_score_type', 'co_applicant_credit_score_type', 'origination_charges', 
                   'discount_points', 'lender_credits', 'interest_rate', 'debt_to_income_ratio', 'combined_loan_to_value_ratio', 
                   'loan_term', 'property_value', 'manufactured_home_secured_property_type', 'total_units', 'aus_1', 'reverse_mortgage', 
                   'open_end_line_of_credit', 'manufactured_home_land_property_interest', 'total_loan_costs', 'total_points_and_fees', 
                   'prepayment_penalty_term', 'negative_amortization', 'interest_only_payment', 'balloon_payment', 
                   'other_nonamortizing_features', 'multifamily_affordable_units']

# %%
# new variable with filtered columns

df_processed = df[columns_to_keep]

# %%
df_processed.head()
# Out:
#    loan_type  loan_amount  action_taken  occupancy_type  census_tract  \
# 0          2       115000             3               1    9003416400
# 1          1       345000             2               1   42017102401
# 2          2       225000             5               1   34039034300
# 3          2       125000             5               1   42055011302
# 4          1       125000             5               1   30111000702
#
#    applicant_ethnicity_1  co_applicant_ethnicity_1  applicant_race_1  \
# 0                      2                         5                 3
# 1                      2                         2                 6
# 2                      1                         1                 5
# 3                      2                         5                 5
# 4                      2                         5                 5
#
#    applicant_race_2  co_applicant_race_1  ...  open_end_line_of_credit  \
# 0               NaN                    8  ...                        2
# 1               NaN                    6  ...                        2
# 2               NaN                    5  ...                        2
# 3               NaN                    8  ...                        2
# 4               NaN                    8  ...                        2
#
#    manufactured_home_land_property_interest  total_loan_costs  \
# 0                                         5               NaN
# 1                                         5               NaN
# 2                                         5               NaN
# 3                                         5               NaN
# 4                                         5               NaN
#
#   total_points_and_fees prepayment_penalty_term  negative_amortization  \
# 0                   NaN                     NaN                      2
# 1                   NaN                     NaN                      2
# 2                   NaN                     NaN                      2
# 3                   NaN                     NaN                      2
# 4                   NaN                     NaN                      2
#
#    interest_only_payment  balloon_payment  other_nonamortizing_features  \
# 0                      2                2                             2
# 1                      2                2                             2
# 2                      2                2                             2
# 3                      2                2                             2
# 4                      2                2                             2
#
#    multifamily_affordable_units
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 41 columns]

# %%
df_processed.describe()
# Out:
#          loan_type   loan_amount  action_taken  occupancy_type  census_tract  \
# count  1100.000000  1.100000e+03   1100.000000     1100.000000  1.100000e+03
# mean      1.497273  2.698091e+05      4.657273        1.136364  2.711167e+10
# std       0.728337  1.691069e+05      1.804804        0.468814  1.631762e+10
# min       1.000000  5.000000e+03      1.000000        1.000000  1.003011e+09
# 25%       1.000000  1.750000e+05      4.000000        1.000000  1.207105e+10
# 50%       1.000000  2.550000e+05      6.000000        1.000000  2.502562e+10
# 75%       2.000000  3.350000e+05      6.000000        1.000000  4.207858e+10
# max       4.000000  3.005000e+06      6.000000        3.000000  5.603997e+10
#
#        applicant_ethnicity_1  co_applicant_ethnicity_1  applicant_race_1  \
# count            1100.000000               1100.000000       1100.000000
# mean                2.124545                  3.811818          4.948182
# std                 0.679839                  1.465418          1.069065
# min                 1.000000                  1.000000          1.000000
# 25%                 2.000000                  2.000000          5.000000
# 50%                 2.000000                  5.000000          5.000000
# 75%                 2.000000                  5.000000          5.000000
# max                 4.000000                  5.000000          7.000000
#
#        applicant_race_2  co_applicant_race_1  ...  open_end_line_of_credit  \
# count         26.000000          1100.000000  ...                   1100.0
# mean          23.730769             6.759091  ...                      2.0
# std            4.548034             1.596504  ...                      0.0
# min           21.000000             1.000000  ...                      2.0
# 25%           21.250000             5.000000  ...                      2.0
# 50%           22.000000             8.000000  ...                      2.0
# 75%           25.000000             8.000000  ...                      2.0
# max           44.000000             8.000000  ...                      2.0
#
#        manufactured_home_land_property_interest  total_loan_costs  \
# count                               1100.000000        772.000000
# mean                                   4.892727       4354.692552
# std                                    0.643680       2886.526591
# min                                    1.000000          0.000000
# 25%                                    5.000000       2316.307500
# 50%                                    5.000000       3320.355000
# 75%                                    5.000000       5473.602500
# max                                    5.000000      19089.900000
#
#        total_points_and_fees  prepayment_penalty_term  negative_amortization  \
# count                    0.0                      0.0                 1100.0
# mean                     NaN                      NaN                    2.0
# std                      NaN                      NaN                    0.0
# min                      NaN                      NaN                    2.0
# 25%                      NaN                      NaN                    2.0
# 50%                      NaN                      NaN                    2.0
# 75%                      NaN                      NaN                    2.0
# max                      NaN                      NaN                    2.0
#
#        interest_only_payment  balloon_payment  other_nonamortizing_features  \
# count            1100.000000           1100.0                        1100.0
# mean                1.997273              2.0                           2.0
# std                 0.052176              0.0                           0.0
# min                 1.000000              2.0                           2.0
# 25%                 2.000000              2.0                           2.0
# 50%                 2.000000              2.0                           2.0
# 75%                 2.000000              2.0                           2.0
# max                 2.000000              2.0                           2.0
#
#        multifamily_affordable_units
# count                           0.0
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
# [8 rows x 38 columns]

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 41 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   loan_type                                 1100 non-null   int64
#  1   loan_amount                               1100 non-null   int64
#  2   action_taken                              1100 non-null   int64
#  3   occupancy_type                            1100 non-null   int64
#  4   census_tract                              1100 non-null   int64
#  5   applicant_ethnicity_1                     1100 non-null   int64
#  6   co_applicant_ethnicity_1                  1100 non-null   int64
#  7   applicant_race_1                          1100 non-null   int64
#  8   applicant_race_2                          26 non-null     float64
#  9   co_applicant_race_1                       1100 non-null   int64
#  10  co_applicant_race_2                       14 non-null     float64
#  11  applicant_sex                             1100 non-null   int64
#  12  co_applicant_sex                          1100 non-null   int64
#  13  applicant_age                             1100 non-null   object
#  14  co_applicant_age                          1100 non-null   object
#  15  income                                    933 non-null    float64
#  16  lien_status                               1100 non-null   int64
#  17  applicant_credit_score_type               1100 non-null   int64
#  18  co_applicant_credit_score_type            1100 non-null   int64
#  19  origination_charges                       772 non-null    float64
#  20  discount_points                           74 non-null     float64
#  21  lender_credits                            51 non-null     float64
#  22  interest_rate                             791 non-null    float64
#  23  debt_to_income_ratio                      232 non-null    object
#  24  combined_loan_to_value_ratio              205 non-null    float64
#  25  loan_term                                 1083 non-null   float64
#  26  property_value                            812 non-null    float64
#  27  manufactured_home_secured_property_type   1100 non-null   int64
#  28  total_units                               1100 non-null   int64
#  29  aus_1                                     1100 non-null   int64
#  30  reverse_mortgage                          1100 non-null   int64
#  31  open_end_line_of_credit                   1100 non-null   int64
#  32  manufactured_home_land_property_interest  1100 non-null   int64
#  33  total_loan_costs                          772 non-null    float64
#  34  total_points_and_fees                     0 non-null      float64
#  35  prepayment_penalty_term                   0 non-null      float64
#  36  negative_amortization                     1100 non-null   int64
#  37  interest_only_payment                     1100 non-null   int64
#  38  balloon_payment                           1100 non-null   int64
#  39  other_nonamortizing_features              1100 non-null   int64
#  40  multifamily_affordable_units              0 non-null      float64
# dtypes: float64(14), int64(24), object(3)
# memory usage: 352.5+ KB

# %% [markdown]
# ## Inspecting categorical columns

# %%
df_processed['applicant_age'].value_counts()
# Out:
# 35-44    271
# 45-54    223
# 25-34    192
# 55-64    165
# 65-74    102
# 8888      76
# >74       54
# <25       17
# Name: applicant_age, dtype: int64

# %%
df_processed['co_applicant_age'].value_counts()
# Out:
# 9999     639
# 35-44    119
# 25-34     84
# 45-54     77
# 55-64     72
# 65-74     47
# 8888      30
# >74       20
# <25       12
# Name: co_applicant_age, dtype: int64

# %%
df_processed['debt_to_income_ratio'].value_counts()
# Out:
# <20%        47
# 20%-<30%    35
# 30%-<36%    31
# 50%-60%     26
# >60%        22
# 37          10
# 43           8
# 44           8
# 36           7
# 38           6
# 39           6
# 45           5
# 48           5
# 41           4
# 49           4
# 42           3
# 40           2
# 46           2
# 47           1
# Name: debt_to_income_ratio, dtype: int64

# %%
target_variable = "action_taken"

# %%
X = df.drop(columns=[target_variable])
y = df[target_variable]

# %%
seed = 123

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=seed)

# %%
X_train

# %%
# 1- loan originated
# 2- application approved but not accepted
# 3- application denied
# 4 - application withdrawn by applicant
# 5 - file closed for incompleteness
# 6 - purchased loan
# 7 - Pre-approval request denied
# 8 - pre-approval request approved but not accepted

y_train.value_counts()
